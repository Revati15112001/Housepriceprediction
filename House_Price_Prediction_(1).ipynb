# %% [markdown]
# <a href="https://colab.research.google.com/github/Revati15112001/Housepriceprediction/blob/main/House_Price_Prediction_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # House Prices Prediction with Machine Learning

# %% [markdown]
# # Introduction:
# The real estate market is a complex and dynamic sector with numerous factors influencing property prices. This project aims to create a machine learning model that can predict house prices based on relevant attributes, helping stakeholders make more informed decisions.

# %% [markdown]
# # Objectives:
# 1.Data Collection: Gather a comprehensive dataset of residential property listings, including features such as square footage, number of bedrooms, location, and more.
#
# 2.Data Preprocessing: Clean and preprocess the data to handle missing values, outliers, and categorical variables. Ensure that the dataset is suitable for training a machine learning model.
#
# 3.Model Building: Develop a machine learning model, such as linear regression,logistic regression. Here we build a Logistic Regression model to predict house prices based on the selected features.
#
# 4.Model Evaluation: Assess the model's performance using appropriate evaluation metrics, such as mean squared error (MSE) or R-squared, to measure its accuracy and reliability.
#
# 5.Accuracy : In last we check the accuracy of Logistic Regression Model.

# %% [markdown]
# # Import The Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# # Read csv file

# %% [markdown]
# # Load the data set into Pandas dataframe

# %%
house=pd.read_csv("C:\\Users\\revat\\Downloads\\House Price Prediction.csv")
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
house.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %% [markdown]
# # Export the data set

# %%
house.drop('date', axis= 1, inplace=True)

# %%
column_to_move = 'price'
new_position = 20
column=house[column_to_move]
house = house.drop(column_to_move, axis=1)
house = pd.concat([house.iloc[:, :new_position], column, house.iloc[:, new_position:]], axis=1)
house
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 2      5631500400         2       1.00          770     10000     1.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21608   263000018         3       2.50         1530      1131     3.0
# 21609  6600060120         4       2.50         2310      5813     2.0
# 21610  1523300141         2       0.75         1020      1350     2.0
# 21611   291310100         3       2.50         1600      2388     2.0
# 21612  1523300157         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
house.columns
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'price'],
#       dtype='object')

# %%
house.shape
# Out:
# (21613, 20)

# %% [markdown]
# # Statistical measures of the Data set

# %%
house.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   4.580302e+09      3.370842      2.114757   2079.899736  1.510697e+04
# std    2.876566e+09      0.930062      0.770163    918.440897  4.142051e+04
# min    1.000102e+06      0.000000      0.000000    290.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    3.904930e+09      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    7.308900e+09      4.000000      2.500000   2550.000000  1.068800e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# # Info gives all the information about Data set

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  zipcode        21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
# ...

# %% [markdown]
# # Plot the data in the form of Histogram

# %% [markdown]
# # Histogram:
# A histogram is a graphical representation of the distribution of data. It is a common tool used in statistics and data analysis to visualize the frequency or occurrence of different values or ranges of values within a dataset. Histograms are particularly useful for understanding the shape, central tendency, and spread of data.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
house.hist(bins = 50, figsize =(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>,
#         <AxesSubplot:title={'center':'sqft_living'}>],
#        [<AxesSubplot:title={'center':'sqft_lot'}>,
#         <AxesSubplot:title={'center':'floors'}>,
#         <AxesSubplot:title={'center':'waterfront'}>,
#         <AxesSubplot:title={'center':'view'}>],
#        [<AxesSubplot:title={'center':'condition'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'sqft_above'}>,
#         <AxesSubplot:title={'center':'sqft_basement'}>],
#        [<AxesSubplot:title={'center':'yr_built'}>,
#         <AxesSubplot:title={'center':'yr_renovated'}>,
#         <AxesSubplot:title={'center':'zipcode'}>,
#         <AxesSubplot:title={'center':'lat'}>],
#        [<AxesSubplot:title={'center':'long'}>,
#         <AxesSubplot:title={'center':'sqft_living15'}>,
# ...

# %%
x=house.iloc[:, :-1].values
y=house.iloc[:, -1].values

# %%
print(x)
# Out:
# [[ 7.12930052e+09  3.00000000e+00  1.00000000e+00 ... -1.22257000e+02
#    1.34000000e+03  5.65000000e+03]
#  [ 6.41410019e+09  3.00000000e+00  2.25000000e+00 ... -1.22319000e+02
#    1.69000000e+03  7.63900000e+03]
#  [ 5.63150040e+09  2.00000000e+00  1.00000000e+00 ... -1.22233000e+02
#    2.72000000e+03  8.06200000e+03]
#  ...
#  [ 1.52330014e+09  2.00000000e+00  7.50000000e-01 ... -1.22299000e+02
#    1.02000000e+03  2.00700000e+03]
#  [ 2.91310100e+08  3.00000000e+00  2.50000000e+00 ... -1.22069000e+02
#    1.41000000e+03  1.28700000e+03]
#  [ 1.52330016e+09  2.00000000e+00  7.50000000e-01 ... -1.22299000e+02
#    1.02000000e+03  1.35700000e+03]]

# %%
print(y)
# Out:
# [221900. 538000. 180000. ... 402101. 400000. 325000.]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state=101)

# %% [markdown]
# # Training and Testing data set

# %%
def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled = np.random.permutation (len(data))
    print(shuffled)
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices= shuffled [test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(house, 0.2)
# Out:
# [  735  2830  4106 ...  5390   860 15795]

# %%
print(f"Rows in train set : {len (train_set)} \nRows in test set : {len (test_set)} \n")
# Out:
# Rows in train set : 17291
# Rows in test set : 4322

# %%
x_train
# Out:
# array([[ 4.01950016e+09,  4.00000000e+00,  2.50000000e+00, ...,
#         -1.22265000e+02,  2.07000000e+03,  4.61000000e+03],
#        [ 6.07323023e+09,  3.00000000e+00,  2.25000000e+00, ...,
#         -1.22184000e+02,  1.80000000e+03,  8.14000000e+03],
#        [ 6.02150084e+09,  5.00000000e+00,  3.00000000e+00, ...,
#         -1.22386000e+02,  1.37000000e+03,  4.60600000e+03],
#        ...,
#        [ 1.54580210e+09,  3.00000000e+00,  2.25000000e+00, ...,
#         -1.22051000e+02,  1.51000000e+03,  7.62500000e+03],
#        [ 2.97980075e+09,  2.00000000e+00,  1.00000000e+00, ...,
#         -1.22317000e+02,  1.46300000e+03,  4.32000000e+03],
#        [ 4.36520062e+09,  3.00000000e+00,  1.00000000e+00, ...,
#         -1.22371000e+02,  1.04000000e+03,  7.74000000e+03]])

# %%
x_test
# Out:
# array([[ 2.13170124e+09,  2.00000000e+00,  1.00000000e+00, ...,
#         -1.21981000e+02,  1.60000000e+03,  9.61600000e+03],
#        [ 2.17500135e+08,  4.00000000e+00,  2.25000000e+00, ...,
#         -1.22335000e+02,  1.89000000e+03,  8.58000000e+03],
#        [ 7.13330038e+09,  4.00000000e+00,  2.50000000e+00, ...,
#         -1.22311000e+02,  1.48000000e+03,  4.30000000e+03],
#        ...,
#        [ 5.12621028e+09,  3.00000000e+00,  2.50000000e+00, ...,
#         -1.21986000e+02,  2.71000000e+03,  1.12820000e+05],
#        [ 7.29960187e+09,  3.00000000e+00,  2.50000000e+00, ...,
#         -1.22198000e+02,  1.60800000e+03,  5.17500000e+03],
#        [ 2.34680027e+09,  3.00000000e+00,  3.00000000e+00, ...,
#         -1.22395000e+02,  2.27000000e+03,  1.81800000e+04]])

# %%
y_train
# Out:
# array([493000., 425000., 588000., ..., 272450., 552000., 394000.])

# %%
y_test
# Out:
# array([349950., 450000., 635000., ..., 560000., 299000., 555000.])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor= RandomForestRegressor (n_estimators = 100, random_state= 0)
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred= regressor.predict(x_test)
np.set_printoptions (precision=2)
print (np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[308560.53 349950.  ]
#  [471245.93 450000.  ]
#  [690520.8  635000.  ]
#  ...
#  [615900.88 560000.  ]
#  [270152.53 299000.  ]
#  [627806.7  555000.  ]]

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23836\3376811405.py in <module>
# ----> 1 accuracy = accuracy_score(y_test, y_pred)
#       2 print(f'Accuracy: {accuracy * 100:.2f}%')
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      91
#      92     if len(y_type) > 1:
# ---> 93         raise ValueError(
# ...

# %%
Mean_absolute_error = mean_absolute_error (y_test,y_pred)
print('Mean absolute_error:',Mean_absolute_error)

Mean_squared_error = mean_squared_error(y_test,y_pred)
print('Mean squared error:',Mean_squared_error)

R_squared = r2_score (y_test,y_pred)
print('R_squared:',R_squared)
# Out:
# Mean absolute_error: 70131.70576616087
# Mean squared error: 18301989929.310535
# R_squared: 0.8710826717260458

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score (x_train_prediction, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23836\934871618.py in <module>
# ----> 1 X_train_prediction = model.predict(X_train)
#       2 training_data_accuracy = accuracy_score (x_train_prediction, y_train)
#
# NameError: name 'model' is not defined
